# %%
import pandas as pd
import numpy as np
df=pd.read_csv("loan_default_prediction_project.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Age                    1000 non-null   int64
#  1   Gender                 792 non-null    object
#  2   Income                 1000 non-null   float64
#  3   Employment_Status      906 non-null    object
#  4   Location               1000 non-null   object
#  5   Credit_Score           1000 non-null   int64
#  6   Debt_to_Income_Ratio   1000 non-null   float64
#  7   Existing_Loan_Balance  1000 non-null   float64
#  8   Loan_Status            1000 non-null   object
#  9   Loan_Amount            1000 non-null   float64
#  10  Interest_Rate          1000 non-null   float64
#  11  Loan_Duration_Months   1000 non-null   int64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 93.9+ KB

# %%
import matplotlib.pyplot as plt
plt.boxplot(df['Credit_Score'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16e66879190>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16e66879640>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16e66878f20>],
#  'medians': [<matplotlib.lines.Line2D at 0x16e66879c70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16e66879fa0>],
#  'means': []}

# %%
plt.boxplot(df['Income'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16e68a61460>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16e68a61a60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16e68a61250>],
#  'medians': [<matplotlib.lines.Line2D at 0x16e68a62090>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16e68a62300>],
#  'means': []}

# %%
plt.boxplot(df['Employment_Status'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 plt.boxplot(df['Employment_Status'])
#
# File c:\Users\shamr\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:2833, in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, capwidths, data)
#    2801 @_copy_docstring_and_deprecators(Axes.boxplot)
#    2802 def boxplot(
#    2803     x: ArrayLike | Sequence[ArrayLike],
#    (...)
#    2831     data=None,
#    2832 ) -> dict[str, Any]:
# -> 2833     return gca().boxplot(
#    2834         x,
#    2835         notch=notch,
#    2836         sym=sym,
#    2837         vert=vert,
#    2838         whis=whis,
# ...

# %%
df=df[df['Employment_Status'].notnull()]
df['Employment_Status'].value_counts()
df['Location'].value_counts()
df['Loan_Status'].value_counts()
# Out:
# Loan_Status
# Non-Default    727
# Default        179
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
#from imblearn.over_sampling import SMOTE
le=LabelEncoder()
df['Employment_Status']=le.fit_transform(df['Employment_Status'])
df['Location']=le.fit_transform(df['Location'])
df['Employment_Status'].value_counts()
df['Location'].value_counts()
df['Loan_Status']=le.fit_transform(df['Loan_Status'])

# %%
plt.boxplot(df['Debt_to_Income_Ratio'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16e6b5a3fe0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16e6b5cbaa0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16e6b5cb4a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x16e6b5f40b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16e6b5f43b0>],
#  'means': []}

# %%
plt.boxplot(df['Employment_Status'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16e6b7a6420>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16e6b7a6a50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16e6b7a61e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x16e6b7a7080>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16e6b7a7380>],
#  'means': []}

# %%
plt.boxplot(df['Location'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16e6b80a240>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16e6b80baa0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16e6b80b320>],
#  'medians': [<matplotlib.lines.Line2D at 0x16e6b8480b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16e6b848260>],
#  'means': []}

# %%
plt.boxplot(df['Credit_Score'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16e6b65f380>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16e6b65f950>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16e6b65f1a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x16e6b65ff80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16e6b690290>],
#  'means': []}

# %%
plt.boxplot(df['Debt_to_Income_Ratio'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16e6b6cdfa0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16e6b6ce510>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16e6b6cdd00>],
#  'medians': [<matplotlib.lines.Line2D at 0x16e6b6ceae0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16e6b6ced50>],
#  'means': []}

# %%
plt.boxplot(df['Existing_Loan_Balance'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16e6b7178f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16e6b717f20>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16e6b717620>],
#  'medians': [<matplotlib.lines.Line2D at 0x16e6b880530>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16e6b880860>],
#  'means': []}

# %%
plt.boxplot(df['Loan_Amount'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16e6b8c5700>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16e6b8c5ca0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16e6b8c54c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x16e6b8c6210>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16e6b8c6540>],
#  'means': []}

# %%
plt.boxplot(df['Loan_Duration_Months'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16e6b912930>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16e6b912f60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16e6b912630>],
#  'medians': [<matplotlib.lines.Line2D at 0x16e6b913560>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16e6b913860>],
#  'means': []}

# %%
plt.boxplot(df['Interest_Rate'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16e6b991610>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16e6b991be0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16e6b991370>],
#  'medians': [<matplotlib.lines.Line2D at 0x16e6b9921e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16e6b9924e0>],
#  'means': []}

# %%
df['Employment_Status'].value_counts()
# Out:
# Employment_Status
# 0    596
# 1    310
# 2     94
# Name: count, dtype: int64

# %%
plt.boxplot(df['Existing_Loan_Balance'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16e6ba00980>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16e6ba00fb0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16e6b9cf620>],
#  'medians': [<matplotlib.lines.Line2D at 0x16e6ba014f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16e6ba017f0>],
#  'means': []}

# %%
#plt.boxplot(df['Income'])
df=df[df['Income']<120000]
plt.boxplot(df['Income'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16e6ba5d760>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16e6ba5dd00>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16e6ba5d640>],
#  'medians': [<matplotlib.lines.Line2D at 0x16e6ba5e300>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16e6ba5e600>],
#  'means': []}

# %%
from scipy.stats import skew
print("Age:",skew(df['Age']))
print("Income:",skew(df['Income']))
print("Employment_Status:",skew(df['Employment_Status']))
print("Location",skew(df["Location"]))
print("Credit_Score:",skew(df["Credit_Score"]))
print("Debt_to_Income_Ratio:",skew(df['Debt_to_Income_Ratio']))
print("Existing_Loan_Balance:",skew(df['Existing_Loan_Balance']))
print("Loan_Amount:",skew(df['Loan_Amount']))
print("Interest_Rate:",skew(df['Interest_Rate']))
print("Loan_Duration:",skew(df['Loan_Duration_Months']))
# Out:
# Age: -0.04824536084944725
# Income: -0.03556328597698036
# Employment_Status: 0.9800381245364792
# Location 0.06808659822605974
# Credit_Score: 0.0443369006365046
# Debt_to_Income_Ratio: 0.04829181773944532
# Existing_Loan_Balance: -0.07050378887654993
# Loan_Amount: -0.048741197635401974
# Interest_Rate: -0.03894617344250753
# Loan_Duration: -0.020070993805505966

# %%
x=df.iloc[:,[0,2,4,5,6,7,9,10,11]]
y=df.iloc[:,[8]]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE(random_state=42)
x_train_over,y_train_over=sm.fit_resample(x_train,y_train)
x_train=pd.DataFrame(x_train_over,columns=x_train.columns)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.model_selection import cross_val_score
lr=RandomForestClassifier()
lr.fit(x_train_over,y_train_over)
y_pred=lr.predict(x_test)
cm=confusion_matrix(y_test,y_pred)
print(cm)
acc=accuracy_score(y_test,y_pred)
print(acc)
scores=cross_val_score(lr,x_train_over,y_train_over,cv=10)
print("cross-validation-scores",scores)
# Out:
# c:\Users\shamr\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1351: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# [[  6  25]
#  [ 28 139]]
# 0.7323232323232324
# c:\Users\shamr\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1351: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\shamr\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1351: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# ...

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.10      0.10      0.10        31
#            1       0.83      0.84      0.84       167
#
#     accuracy                           0.73       198
#    macro avg       0.47      0.47      0.47       198
# weighted avg       0.72      0.73      0.72       198
